# %% [markdown]
# <a href="https://colab.research.google.com/github/m-edal/Earth-Env-DS-MSc-Course/blob/main/labs/W8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # W8: Advanced Data Visualization
# - Contributer: Dr. Zhonghua Zheng, Yuan Sun
# - Course Unit: Earth and Environmental Data Science (EART60702)
# - Last modified date: 23 March, 2026

# %% [markdown]
# ## Intended Learning Outcomes (ILOs)
# - Data visualization with Cartopy: develop advanced skills in visualizing geospatial data using specialized tools such as Cartopy, and learn how to create interactive and informative maps that effectively communicate complex spatial patterns and relationships.
# - Geo-map analysis: understand cartographic principles and techniques, including map projection, coordinate systems, symbolization, and thematic mapping.

# %% [markdown]
# ## 1. Cartopy (20mins)
# - Cartopy is a Python package designed for geospatial data processing in order to produce maps and other geospatial data analyses. Cartopy document: https://scitools.org.uk/cartopy/docs/latest/getting_started/index.html.
# - Key features of cartopy are its object oriented projection definitions, and its ability to transform points, lines, vectors, polygons and images between those projections.
# - Cartopy has exposed an interface to enable easy map creation using matplotlib.

# %%
# install cartopy in the conda environment
# !pip install cartopy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cartopy in /Users/user/Library/Python/3.9/lib/python/site-packages (0.22.0)
# Requirement already satisfied: numpy>=1.21 in /Users/user/Library/Python/3.9/lib/python/site-packages (from cartopy) (1.25.2)
# Requirement already satisfied: matplotlib>=3.4 in /Users/user/Library/Python/3.9/lib/python/site-packages (from cartopy) (3.7.2)
# Requirement already satisfied: shapely>=1.7 in /Users/user/Library/Python/3.9/lib/python/site-packages (from cartopy) (1.8.5)
# Requirement already satisfied: packaging>=20 in /Users/user/Library/Python/3.9/lib/python/site-packages (from cartopy) (23.1)
# Requirement already satisfied: pyshp>=2.1 in /Users/user/Library/Python/3.9/lib/python/site-packages (from cartopy) (2.3.1)
# Requirement already satisfied: pyproj>=3.1.0 in /Users/user/Library/Python/3.9/lib/python/site-packages (from cartopy) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/user/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.4->cartopy) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Users/user/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.4->cartopy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/user/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.4->cartopy) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/user/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.4->cartopy) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /Users/user/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.4->cartopy) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/user/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.4->cartopy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/user/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.4->cartopy) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/user/Library/Python/3.9/lib/python/site-packages (from matplotlib>=3.4->cartopy) (6.0.1)
# Requirement already satisfied: certifi in /Users/user/Library/Python/3.9/lib/python/site-packages (from pyproj>=3.1.0->cartopy) (2023.7.22)
# Requirement already satisfied: zipp>=3.1.0 in /Users/user/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.4->cartopy) (3.16.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.4->cartopy) (1.15.0)

# %%
# import package
import cartopy.crs as ccrs # import projections
import cartopy.feature as cf # import features
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np

# %% [markdown]
# ## Basemap and mapping
# - visualize './data/W8.nc/': https://github.com/m-edal/Earth-Env-DS-MSc-Course/blob/main/labs/data/W8.nc The original data comes from https://figshare.com/collections/A_global_dataset_of_air_temperature_derived_from_satellite_remote_sensing_and_weather_stations/4081802.
#
# raw_data = xr.open_dataset('Tair_SG_2005.nc')
# raw_data_1yr = raw_data.sel('time' = '1970-01-01 00:00:00')
# raw_data_1yr.to_netcdf('W8.nc')

# %%
# Creating a basic map is as simple as telling Matplotlib to use a specific map projection, and then adding some coastlines to the axes
ax = plt.axes(projection=ccrs.PlateCarree()) # specify projection
ax.coastlines() # add coastlines
ax.stock_img() # add an underlay image to the map
lon_min = -180
lon_max = 180
lat_min = -90
lat_max = 90
ax.set_extent([lon_min, lon_max, lat_min, lat_max])
ax.get_extent() # Get the extent (x0, x1, y0, y1) of the map in the given coordinate system
ax.set_xticks(range(lon_min, lon_max +1, 90)) # add xticks
ax.set_yticks(range(lat_min, lat_max + 1, 45))
# Out:
# [<matplotlib.axis.YTick at 0x2bfafa735e0>,
#  <matplotlib.axis.YTick at 0x2bfafa56f40>,
#  <matplotlib.axis.YTick at 0x2bfafa56460>,
#  <matplotlib.axis.YTick at 0x2bfafac1e20>,
#  <matplotlib.axis.YTick at 0x2bfafac7910>]

# %%
labelcolor = '#05101f'
labelfont = 8
ax2 = plt.axes(projection=ccrs.Mollweide()) 
ax2.add_feature(cf.LAND)
ax2.add_feature(cf.RIVERS)
ax2.add_feature(cf.LAKES)
ax2.coastlines(edgecolor=labelcolor, alpha = 0.2)
ax2.add_feature(cf.BORDERS, edgecolor=labelcolor, alpha = 0.2)
grid = ax2.gridlines(draw_labels=True, x_inline=False, y_inline=False, linestyle='--')
grid.xlabel_style = {'color': labelcolor, 'fontsize': labelfont}
grid.ylabel_style = {'color': labelcolor, 'fontsize': labelfont}

# %%
ds = xr.open_dataset('./data/W8.nc') # global data
ds
# Out:
# <xarray.Dataset> Size: 1MB
# Dimensions:  (lat: 360, lon: 720)
# Coordinates:
#   * lon      (lon) float64 6kB -179.8 -179.2 -178.8 -178.2 ... 178.8 179.2 179.8
#   * lat      (lat) float64 3kB 89.75 89.25 88.75 88.25 ... -88.75 -89.25 -89.75
#     time     datetime64[ns] 8B ...
# Data variables:
#     Tair     (lat, lon) float32 1MB ...
#     crs      |S1 1B ...
# Attributes: (12/32)
#     created_by:                 R, packages ncdf4 and raster (version 2.6-7)
#     date:                       2018-07-25 12:07:05
#     title:                      Air Temperature at 2m
#     product_version:            1.0
#     Conventions:                CF-1.7
#     standard_name_vocabulary:   NetCDF Climate Forecast (CF) Metadata Convent...
#     ...                         ...
#     keywords_vocabulary:        GCMD Science Keywords, Version 8.6
#     comment:
#     license:                    free and open access
#     cdm_data_type:              Grid
#     crs:                        +proj=longlat +datum=WGS84 +no_defs +ellps=WG...
#     crs_format:                 PROJ.4

# %%
ax3 = plt.axes(projection=ccrs.Mollweide()) 
ax3.coastlines(edgecolor=labelcolor, alpha = 0.2)
ax3.add_feature(cf.BORDERS, edgecolor=labelcolor, alpha = 0.2)
grid = ax3.gridlines(draw_labels=True, x_inline=False, y_inline=False, linestyle='--')
grid.xlabel_style = {'color': labelcolor, 'fontsize': labelfont}
grid.ylabel_style = {'color': labelcolor, 'fontsize': labelfont}
mesh = ax3.pcolormesh(ds.lon, ds.lat, ds.Tair, transform=ccrs.PlateCarree(), cmap='viridis')

# %% [markdown]
# Q1: add a data mask to the grid cells where temperature is higher than 295K.

# %%
ax3 = plt.axes(projection=ccrs.Mollweide()) 
ax3.coastlines(edgecolor=labelcolor, alpha = 0.2)
ax3.add_feature(cf.BORDERS, edgecolor=labelcolor, alpha = 0.2)
grid = ax3.gridlines(draw_labels=True, x_inline=False, y_inline=False, linestyle='--')
grid.xlabel_style = {'color': labelcolor, 'fontsize': labelfont}
grid.ylabel_style = {'color': labelcolor, 'fontsize': labelfont}
mesh = ax3.pcolormesh(ds.lon, ds.lat, np.ma.masked_where(ds.Tair > 295,ds.Tair), transform=ccrs.PlateCarree(), cmap='viridis')

# %% [markdown]
# Q2: please visualize './data/W6.nc/': https://github.com/m-edal/Earth-Env-DS-MSc-Course/blob/main/labs/data/W6.nc through 2 ways: 'pcolormesh()' and 'contourf()'
# - pcolormesh(): https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.pcolormesh.html
# - contourf(): https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.contourf.html

# %%
ds = xr.open_dataset('./data/W6.nc') # regional data
ds
# Out:
# <xarray.Dataset> Size: 4kB
# Dimensions:    (longitude: 21, latitude: 21, time: 1)
# Coordinates:
#   * longitude  (longitude) float32 84B -5.0 -4.75 -4.5 -4.25 ... -0.5 -0.25 0.0
#   * latitude   (latitude) float32 84B 55.0 54.75 54.5 54.25 ... 50.5 50.25 50.0
#   * time       (time) datetime64[ns] 8B 2012-12-12T12:00:00
# Data variables:
#     t2m        (time, latitude, longitude) float64 4kB ...
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-03-02 22:32:39 GMT by grib_to_netcdf-2.25.1: /opt/ecmw...

# %%
longitude = ds.longitude.values
latitude = ds.latitude.values
data = ds.t2m.values[0]

# Create a new plot with PlateCarree projection
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

# Define contour levels
levels = 20  # Number of contour levels

# Determine data range
vmin = data.min()
vmax = data.max()

# Plot your data on the map
im = ax.contourf(longitude, latitude, data, levels=levels, vmin=vmin, vmax=vmax, transform=ccrs.PlateCarree(), cmap='viridis')

# Add coastlines
ax.coastlines()

# Add colorbar
cbar = fig.colorbar(im, ax=ax, orientation='vertical', fraction=0.025, pad=0.04)
cbar.set_label('2-m temperature (K)')

# Add title
plt.title('2012-12-12T12:00:00')

plt.show()

# %%
# Create a new plot with PlateCarree projection
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

# Plot your data on the map using pcolormesh
mesh = ax.pcolormesh(longitude, latitude, data, transform=ccrs.PlateCarree(), cmap='viridis')

# Add coastlines
ax.coastlines()

# Add colorbar
cbar = fig.colorbar(mesh, ax=ax, orientation='vertical', fraction=0.025, pad=0.04)
cbar.set_label('2-m temperature (K)')

# Add title
plt.title('2012-12-12T12:00:00')

plt.show()

# %% [markdown]
# ## Open Street Map plot using cartopy

# %%
import cartopy.io.img_tiles as cimgt # 'img_tiles' containes functions handlling image tiles for map plotting

# %%
request = cimgt.OSM()
extent = [-2.275, -2.2186, 53.47, 53.50] # set extend of the figure [lon_min, lon_max, lat_min, lat_max]

ax = plt.axes(projection=request.crs)
ax.set_extent(extent)

ax.add_image(request, 13) # 13 is the zoom level
plt.show()

# %%
# mapping by a center point (latitude, longitude)
center_lat = 53.4668
center_lon = -2.2339

# Width and height of the map in degrees
width_deg = 0.0025
height_deg = 0.001

# Calculate extent based on center point, width, and height
min_lon = center_lon - (width_deg / 2)
max_lon = center_lon + (width_deg / 2)
min_lat = center_lat - (height_deg / 2)
max_lat = center_lat + (height_deg / 2)
extent = [min_lon, max_lon, min_lat, max_lat]

plt.figure(figsize=(8, 6))
# Request map tiles
req = cimgt.OSM()
ax = plt.axes(projection=req.crs)
ax.set_extent(extent)
ax.add_image(req, 19)  # Adjust zoom level as needed
plt.show()

# NOTE: zoom specifications should be selected based on extent:
# -- 2     = coarse image, select for worldwide or continental scales
# -- 4-6   = medium coarseness, select for countries and larger states
# -- 6-10  = medium fineness, select for smaller states, regions, and cities
# -- 10-12 = fine image, select for city boundaries and zip codes
# -- 14+   = extremely fine image, select for roads, blocks, buildings

# %% [markdown]
# Other practises:
# - https://www.theurbanist.com.au/2021/03/plotting-openstreetmap-images-with-cartopy/
# - https://makersportal.com/blog/2020/4/24/geographic-visualizations-in-python-with-cartopy
